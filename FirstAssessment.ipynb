# %% [markdown]
# <a href="https://colab.research.google.com/github/anilalperr/AitFirstClass/blob/main/FirstAssessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
homer_img = Image.open('homer.jpg') 
pixel_map = homer_img.load()
width, height = homer_img.size
for w in range(width-30, width):
  for h in range(30):
    pixel_map[w, h] = (0,0,0)
homer_img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1200x1200 at 0x7FC5CF705F70>
